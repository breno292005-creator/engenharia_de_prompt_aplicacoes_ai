# %% [markdown]
# <a href="https://colab.research.google.com/github/breno292005-creator/engenharia_de_prompt_aplicacoes_ai/blob/main/aula07_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula: Programação Assistida
# Breno Amorim

# %% [markdown]
# ### Soma de Lista

# %%
numeros = [1, 2, 3, 4, 5]
soma = 0
i = 0
while i < len(numeros):
  soma += numeros[i]
  i += 1
print(numeros)
print(soma)
# Out:
# [1, 2, 3, 4, 5]
# 15

# %%
numeros = [1, 2, 6, 9, 11] # Inicializa uma lista de números inteiros
soma = 0 # Inicializa uma variável para armazenar a soma

# Itera sobre cada número na lista 'numeros'
for num in numeros:
  soma += num # Adiciona o número atual à soma

print(soma) # Imprime o valor final da soma
# Out:
# 29

# %%
# Exemplo de uso da função
minha_lista = [10, 20, 30, 5]
soma_total = somar_lista_numeros(minha_lista)
print(f"A lista é: {minha_lista}")
print(f"A soma dos números na lista é: {soma_total}")

# %% [markdown]
# ### Eh primo

# %% [markdown]
# ### Inversão String

# %% [markdown]
# # Mini projeto
